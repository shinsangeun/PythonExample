# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path='./chipotle.csv'

# %%
chipo=pd.read_csv(file_path)
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
# 가장 많이 팔린 메뉴

# 차트 크기 조정 (가로, 세로)
plt.rcParams["figure.figsize"]=(20,10)

# 차트 눈금선 표기
plt.rcParams['axes.grid']=True

# item_name과 quantity를 별도로 추출
temp_df=pd.DataFrame({'item_name':temp.index, 'quantity':temp.values})
x=temp_df['item_name']
y=temp_df['quantity']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c698d98de419> in <module>
#       8
#       9 # item_name과 quantity를 별도로 추출
# ---> 10 temp_df=pd.DataFrame({'item_name':temp.index, 'quantity':temp.values})
#      11 x=temp_df['item_name']
#      12 y=temp_df['quantity']
#
# NameError: name 'temp' is not defined
